# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  LOAD DATA USING LIBRARY PANDAS

# %%
df=pd.read_csv('housing_data.csv')

# %% [markdown]
# FIRST FIVE ROWS

# %%
df.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %% [markdown]
# SHAPE OF DEPENDENT VARIABLE

# %%
df['SalePrice'].shape
# Out:
# (1460,)

# %% [markdown]
# FIRST FIVE ROWS

# %%
df['MSSubClass'].unique()
# Out:
# array(['SC60', 'SC20', 'SC70', 'SC50', 'SC190', 'SC45', 'SC90', 'SC120',
#        'SC30', 'SC85', 'SC80', 'SC160', 'SC75', 'SC180', 'SC40'],
#       dtype=object)

# %% [markdown]
# Changing the name of the values in the column MSSubclass

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC60':'2-STORY 1946 & NEWER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC20':'1-STORY 1946 & NEWER ALL STYLES'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC70':'2-STORY 1945 & OLDER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC50':'1-1/2 STORY FINISHED ALL AGES'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC190':'2 FAMILY CONVERSION - ALL STYLES AND AGES'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC45':'1-1/2 STORY - UNFINISHED ALL AGES'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC90':'DUPLEX - ALL STYLES AND AGES'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC120':'1-STORY PUD (Planned Unit Development) - 1946 & NEWER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC30':'1-STORY 1945 & OLDER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC85':'SPLIT FOYER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC80':'SPLIT OR MULTI-LEVEL'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC160':'2-STORY PUD - 1946 & NEWER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC75':'2-1/2 STORY ALL AGES'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC180':'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC40':'1-STORY W/FINISHED ATTIC ALL AGES'})

# %% [markdown]
# Checking the unique values after changing the values names

# %%
df['MSSubClass'].unique()
# Out:
# array(['2-STORY 1946 & NEWER', '1-STORY 1946 & NEWER ALL STYLES',
#        '2-STORY 1945 & OLDER', '1-1/2 STORY FINISHED ALL AGES',
#        '2 FAMILY CONVERSION - ALL STYLES AND AGES',
#        '1-1/2 STORY - UNFINISHED ALL AGES',
#        'DUPLEX - ALL STYLES AND AGES',
#        '1-STORY PUD (Planned Unit Development) - 1946 & NEWER',
#        '1-STORY 1945 & OLDER', 'SPLIT FOYER', 'SPLIT OR MULTI-LEVEL',
#        '2-STORY PUD - 1946 & NEWER', '2-1/2 STORY ALL AGES',
#        'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER',
#        '1-STORY W/FINISHED ATTIC ALL AGES'], dtype=object)

# %% [markdown]
# Information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# Statistical values of the dataframe

# %%
df.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# Finding the null values in the dataframe

# %%
missing=df.isnull().sum()
missing
# Out:
# Unnamed: 0          0
# MSSubClass          0
# MSZoning            0
# LotFrontage         0
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          0
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinSF1          0
# BsmtFinType2        0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# Dropping the Column MasVnrType

# %%
df.drop(['MasVnrType'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0                       MSSubClass MSZoning  LotFrontage  LotArea  \
# 0           0             2-STORY 1946 & NEWER       RL           65     8450
# 1           1  1-STORY 1946 & NEWER ALL STYLES       RL           80     9600
# 2           2             2-STORY 1946 & NEWER       RL           68    11250
# 3           3             2-STORY 1945 & OLDER       RL           60     9550
# 4           4             2-STORY 1946 & NEWER       RL           84    14260
#
#   Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# ...

# %% [markdown]
# Dropping the column Unnamed

# %%
df.drop(['Unnamed: 0','Alley'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                         MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0             2-STORY 1946 & NEWER       RL           65     8450   Pave
# 1  1-STORY 1946 & NEWER ALL STYLES       RL           80     9600   Pave
# 2             2-STORY 1946 & NEWER       RL           68    11250   Pave
# 3             2-STORY 1945 & OLDER       RL           60     9550   Pave
# 4             2-STORY 1946 & NEWER       RL           84    14260   Pave
#
#   LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0      Reg         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1      Reg         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2      IR1         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3      IR1         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4      IR1         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
# ...

# %% [markdown]
# Filling the null values in the column GarageYrBlt by median

# %%
df['GarageYrBlt'].fillna(df['GarageYrBlt'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       1
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# ...

# %% [markdown]
# Filling the null values in the column Electrical by mean

# %%
df['Electrical'].fillna(df['Electrical'].mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# ...

# %%
df.head()
# Out:
#                         MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0             2-STORY 1946 & NEWER       RL           65     8450   Pave
# 1  1-STORY 1946 & NEWER ALL STYLES       RL           80     9600   Pave
# 2             2-STORY 1946 & NEWER       RL           68    11250   Pave
# 3             2-STORY 1945 & OLDER       RL           60     9550   Pave
# 4             2-STORY 1946 & NEWER       RL           84    14260   Pave
#
#   LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0      Reg         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1      Reg         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2      IR1         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3      IR1         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4      IR1         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
# ...

# %% [markdown]
# Univariate analysis of categorical data. We’ll be using the count plot function from the seaborn library

# %%
df['MSSubClass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='MSSubClass'>

# %% [markdown]
# Changing the name of the values in the column MSZoning

# %%
df['MSZoning']=df['MSZoning'].replace({'RL':'Residential Low Density'})

# %%
df['MSZoning']=df['MSZoning'].replace({'RM':'Residential Medium Density'})

# %%
df['MSZoning']=df['MSZoning'].replace({'C (all)':'Commercial'})

# %%
df['MSZoning']=df['MSZoning'].replace({'FV':'Floating Village Residential'})

# %%
df['MSZoning']=df['MSZoning'].replace({'RH':'Residential High Density'})

# %%
df.rename(columns={'MSZoning': 'Zoning Category'}, inplace=True)

# %%
df['Zoning Category'].unique()
# Out:
# array(['Residential Low Density', 'Residential Medium Density',
#        'Commercial', 'Floating Village Residential',
#        'Residential High Density'], dtype=object)

# %% [markdown]
# Univariate analysis of categorical data. We’ll be using the count plot function from the seaborn library

# %%
x = df['Zoning Category'].value_counts() 
plt.pie(x.values, 
        labels=x.index, 
        autopct='%1.1f%%') 
plt.show()

# %% [markdown]
# Replacing the name of the values in the column Shape of the property

# %%
df['LotShape']=df['LotShape'].replace({'Reg':'Regular'})

# %%
df['LotShape']=df['LotShape'].replace({'IR1':'Slightly irregular'})

# %%
df['LotShape']=df['LotShape'].replace({'IR2':'Moderately Irregular'})

# %%
df['LotShape']=df['LotShape'].replace({'IR3':'Irregular'})

# %%
df['LotShape'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Univariate analysis of categorical data. We’ll be using the count plot function from the seaborn library

# %%
df['LotShape'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='LotShape'>

# %% [markdown]
# **Replacing the name of the values in the column Shape of the property**

# %%
df['LandContour']=df['LandContour'].replace({'Lvl':'Near Flat/Level'})

# %%
df['LandContour']=df['LandContour'].replace({'Bnk':'Banked - Quick and significant rise from street grade to building'})

# %%
df['LandContour'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['LandContour'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='LandContour'>

# %% [markdown]
# **Replacing the name of the values in the column Type of utilities**

# %%
df['Utilities']=df['Utilities'].replace({'AllPub':'All public Utilities (E,G,W,& S)'})

# %%
df['Utilities']=df['Utilities'].replace({'NoSewr':'Electricity, Gas, and Water (Septic Tank)'})

# %%
df['Utilities']=df['Utilities'].replace({'NoSeWa':'Electricity and Gas Only'})

# %%
df['Utilities']=df['Utilities'].replace({'ELO':'Electricity only'})

# %%
df['Utilities'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['LotConfig']=df['LotConfig'].replace({'Inside':'Inside lot'})

# %%
df['LotConfig']=df['LotConfig'].replace({'Corner':'Corner lot'})

# %%
df['LotConfig']=df['LotConfig'].replace({'CulDSac':'Cul-de-sac'})

# %%
df['LotConfig']=df['LotConfig'].replace({'FR2':'Frontage on 2 sides of property'})

# %%
df['LotConfig']=df['LotConfig'].replace({'FR3':'Frontage on 3 sides of property'})

# %%
df['LotConfig'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['LandSlope']=df['LandSlope'].replace({'Gtl':'Gentle slope'})

# %%
df['LandSlope']=df['LandSlope'].replace({'Mod':'Moderate Slope'})

# %%
df['LandSlope']=df['LandSlope'].replace({'Sev':'Severe Slope'})

# %%
df['LandSlope'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='LandSlope'>

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Blmngtn':'Bloomington Heights'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Blueste':'Bluestem'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'BrDale':'Briardale'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'BrkSide':'Brookside'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'ClearCr':'Clear Creek'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'CollgCr':'College Creek'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Crawfor':'Crawford'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Edwards':'Edwards'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'IDOTRR':'Iowa DOT and Rail Road'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'MeadowV':'Meadow Village'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Mitchel':'Mitchell'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Names':'North Ames'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'NoRidge':'Northridge'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'NPkVill':'Northpark Villa'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'NridgHt':'Northridge Heights'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'NWAmes':'Northwest Ames'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'OldTown':'Old Town'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'SWISU':'South & West of Iowa State University'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'SawyerW':'Sawyer West'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Somerst':'Somerset'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'StoneBr':'Stone Brook'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Timber':'Timberland'})

# %%
df['Neighborhood'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Neighborhood'>

# %% [markdown]
# **Replacing the column name**

# %%
df.rename(columns={'MSZoning': 'Zoning Category'}, inplace=True)

# %%
df.rename(columns={'Street': 'Type of Road'}, inplace=True)

# %%
df.rename(columns={'Alley': 'Type of Alley'}, inplace=True)

# %%
df.rename(columns={'LotShape': 'Shape of Property'}, inplace=True)

# %%
df.rename(columns={'LandContour': 'Property Flatness'}, inplace=True)

# %%
df.rename(columns={'Utilities': 'Type of utilities'}, inplace=True)

# %%
df.rename(columns={'LotConfig': 'Lot configuration'}, inplace=True)

# %%
df.rename(columns={'LandSlope': 'slope of property'}, inplace=True)

# %%
df.rename(columns={'BldgType': 'Type of dwelling'}, inplace=True)

# %%
df.rename(columns={'HouseStyle': 'Style of dwelling'}, inplace=True)

# %%
df.rename(columns={'YearBuilt': 'Year Built'}, inplace=True)

# %%
df.rename(columns={'RoofStyle': 'Type of roof'}, inplace=True)

# %%
df.rename(columns={'RoofMatl': 'Roof material'}, inplace=True)

# %%
df.rename(columns={'MasVnrType': 'Masonry veneer type'}, inplace=True)

# %%
df.rename(columns={'MasVnrArea': 'Masonry veneer area'}, inplace=True)

# %%
new_df = df[['LotFrontage','LotArea','OverallQual','OverallCond','Year Built','YearRemodAdd','Masonry veneer area','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageYrBlt','GarageCars','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','YrSold','SalePrice']]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# **Univariate analysis**

# %%
df['Condition1'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Condition1'>

# %%
df['Condition2'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Condition2'>

# %%
df['Style of dwelling'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Style of dwelling'>

# %%
df['Type of dwelling'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type of dwelling'>

# %%
df['Type of roof'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Type of roof'>

# %%
df['Roof material'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Roof material'>

# %%
df['Exterior1st'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Exterior1st'>

# %%
df['Exterior2nd'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Exterior2nd'>

# %%
df['ExterQual'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
x = df['ExterQual'].value_counts() 
plt.pie(x.values, 
        labels=x.index, 
        autopct='%1.1f%%') 
plt.show()

# %%
df['ExterCond'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ExterCond'>

# %%
df['Foundation'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Foundation'>

# %%
df['BsmtQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BsmtQual'>

# %%
df['BsmtCond'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BsmtCond'>

# %%
df['BsmtExposure'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BsmtExposure'>

# %%
df['BsmtFinType1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BsmtFinType1'>

# %%
df['BsmtFinType2'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BsmtFinType2'>

# %%
df['Heating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Heating'>

# %%
df['HeatingQC'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeatingQC'>

# %%
df['CentralAir'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Electrical'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Electrical'>

# %%
df['GarageType'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageType'>

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['GarageCond'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageCond'>

# %%
df['SaleType'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SaleType'>

# %%
df['SaleCondition'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SaleCondition'>

# %% [markdown]
# **exploring bivariate relationships by calculating correlations and creating scatterplots between 'SalePrice' and other variables**

# %%
correlation = df['LotArea'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.26384335387140573

# %%
sns.scatterplot(x='LotArea',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='LotArea', ylabel='SalePrice'>

# %%
correlation = df['Year Built'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.5228973328794969

# %%
correlation=df['Year Built'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.5228973328794969

# %%
sns.scatterplot(x='Year Built',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='Year Built', ylabel='SalePrice'>

# %%
correlation = df['OverallQual'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.7909816005838047

# %%
sns.scatterplot(x='OverallQual',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %%
correlation = df['OverallCond'].corr(df['SalePrice'])
print(correlation)
# Out:
# -0.07785589404867801

# %%
sns.scatterplot(x='OverallCond',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='OverallCond', ylabel='SalePrice'>

# %%
correlation = df['GrLivArea'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.7086244776126522

# %%
sns.scatterplot(x='GrLivArea',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %%
correlation = df['FullBath'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.5606637627484456

# %%
sns.scatterplot(x='FullBath',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='FullBath', ylabel='SalePrice'>

# %%
correlation = df['HalfBath'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.2841076755947829

# %%
sns.scatterplot(x='HalfBath',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='HalfBath', ylabel='SalePrice'>

# %%
correlation = df['BedroomAbvGr'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.16821315430074

# %%
sns.scatterplot(x='BedroomAbvGr',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='BedroomAbvGr', ylabel='SalePrice'>

# %%
correlation = df['KitchenAbvGr'].corr(df['SalePrice'])
print(correlation)
# Out:
# -0.1359073708421411

# %%
sns.scatterplot(x='KitchenAbvGr',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='KitchenAbvGr', ylabel='SalePrice'>

# %%
correlation = df['GarageCars'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.6404091972583531

# %%
sns.scatterplot(x='GarageCars',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='GarageCars', ylabel='SalePrice'>

# %%
correlation = df['GarageArea'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.6234314389183617

# %%
sns.scatterplot(x='GarageArea',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='GarageArea', ylabel='SalePrice'>

# %%
correlation = df['GarageYrBlt'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.4667536523633397

# %%
sns.scatterplot(x='GarageYrBlt',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='GarageYrBlt', ylabel='SalePrice'>

# %%
correlation = df['YearRemodAdd'].corr(df['SalePrice'])
print(correlation)
# Out:
# 0.5071009671113865

# %%
sns.scatterplot(x='YearRemodAdd',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='YearRemodAdd', ylabel='SalePrice'>

# %% [markdown]
# **BIVARIATE ANALYSIS**
# **Categorical vs Numerical**

# %%
sns.boxplot(x='OverallQual', y='SalePrice', data=df)
plt.show()

# %%
sns.boxplot(x='OverallCond', y='SalePrice', data=df)
plt.show()

# %%
sns.boxplot(x='Year Built', y='SalePrice', data=df)
plt.show()

# %%
sns.boxplot(x='YearRemodAdd', y='SalePrice', data=df)
plt.show()

# %%
sns.boxplot(x='TotalBsmtSF', y='SalePrice', data=df)
plt.show()

# %%
sns.boxplot(x='GrLivArea', y='SalePrice', data=df)
plt.show()

# %%
sns.violinplot(x='GarageCars', y='SalePrice', data=df)
plt.show()

# %%
sns.violinplot(x='GarageArea', y='SalePrice', data=df)
plt.show()

# %% [markdown]
# **BIVARIATE ANALYSIS**
# **NUMERICAL VS NUMERICAL**

# %%
sns.scatterplot(x='GrLivArea', y='TotalBsmtSF', data=df)
plt.show()

# %%
sns.scatterplot(x='GrLivArea', y='2ndFlrSF', data=df)
plt.show()

# %%
sns.scatterplot(x='TotalBsmtSF', y='1stFlrSF', data=df)
plt.show()

# %%
sns.scatterplot(x='TotalBsmtSF', y='2ndFlrSF', data=df)
plt.show()

# %%
sns.scatterplot(x='1stFlrSF', y='2ndFlrSF', data=df)
plt.show()

# %% [markdown]
# **Analyzing Correlation in a Dataset**

# %%
correlation_matrix = df.select_dtypes(include=['number']).corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
price_correlations = correlation_matrix['SalePrice'].sort_values(ascending=False)
price_correlations
# Out:
# SalePrice              1.000000
# OverallQual            0.790982
# GrLivArea              0.708624
# GarageCars             0.640409
# GarageArea             0.623431
# TotalBsmtSF            0.613581
# 1stFlrSF               0.605852
# FullBath               0.560664
# TotRmsAbvGrd           0.533723
# Year Built             0.522897
# YearRemodAdd           0.507101
# Masonry veneer area    0.472614
# Fireplaces             0.466929
# GarageYrBlt            0.466754
# BsmtFinSF1             0.386420
# WoodDeckSF             0.324413
# 2ndFlrSF               0.319334
# OpenPorchSF            0.315856
# HalfBath               0.284108
# LotArea                0.263843
# BsmtFullBath           0.227122
# BsmtUnfSF              0.214479
# LotFrontage            0.209624
# BedroomAbvGr           0.168213
# ScreenPorch            0.111447
# PoolArea               0.092404
# 3SsnPorch              0.044584
# BsmtFinSF2            -0.011378
# BsmtHalfBath          -0.016844
# ...

# %%
price_correlations.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **Removing Outliers and Visualizing Data Before and After**

# %%
q1 = df['SalePrice'].quantile(0.25)
q3 = df['SalePrice'].quantile(0.75)
iqr=q3-q1

# %%
lower_limit=q1-1.5*iqr

# %%
upper_limit=q3+1.5*iqr

# %%
df.plot(kind='box')
plt.show()

# %%
df['SalePrice'].shape
# Out:
# (1460,)

# %%
df['SalePrice'].plot(kind='box')
plt.show()

# %%
outliers4= df[(df['SalePrice'] > upper_limit) | (df['SalePrice'] < lower_limit)]
outliers4
# Out:
#                                              MSSubClass  \
# 11                                 2-STORY 1946 & NEWER
# 53                      1-STORY 1946 & NEWER ALL STYLES
# 58                                 2-STORY 1946 & NEWER
# 112                                2-STORY 1946 & NEWER
# 151                     1-STORY 1946 & NEWER ALL STYLES
# 161                                2-STORY 1946 & NEWER
# 178                     1-STORY 1946 & NEWER ALL STYLES
# 185                                2-1/2 STORY ALL AGES
# 224                     1-STORY 1946 & NEWER ALL STYLES
# 231                                2-STORY 1946 & NEWER
# 278                     1-STORY 1946 & NEWER ALL STYLES
# 309                     1-STORY 1946 & NEWER ALL STYLES
# 313                     1-STORY 1946 & NEWER ALL STYLES
# 320                                2-STORY 1946 & NEWER
# 321                                2-STORY 1946 & NEWER
# 336                     1-STORY 1946 & NEWER ALL STYLES
# ...

# %%
zscore=(df['SalePrice']-df['SalePrice'].mean())/df['SalePrice'].std()
zscore
# Out:
# 0       0.347154
# 1       0.007286
# 2       0.535970
# 3      -0.515105
# 4       0.869545
# 5      -0.477341
# 6       1.587045
# 7       0.240159
# 8      -0.642241
# 9      -0.792034
# 10     -0.647276
# 11      2.065378
# 12     -0.464754
# 13      1.240882
# 14     -0.301113
# 15     -0.615806
# 16     -0.401815
# 17     -1.144491
# 18     -0.275938
# 19     -0.527692
# 20      1.817400
# 21     -0.522657
# 22      0.617790
# 23     -0.642241
# 24     -0.338876
# 25      0.948847
# 26     -0.580561
# 27      1.574457
# 28      0.334567
# 29     -1.415127
# 30     -1.773877
# 31     -0.397409
# 32     -0.012855
# 33     -0.194118
# 34      1.215707
# 35      1.612220
# 36     -0.452166
# 37     -0.351464
# 38     -0.905324
# 39     -1.245192
# 40     -0.263350
# 41     -0.137473
# 42     -0.464754
# 43     -0.637835
# 44     -0.502517
# 45      1.749426
# 46      0.739715
# 47      0.865768
# 48     -0.854973
# 49     -0.678745
# 50     -0.049359
# 51     -0.836091
# ...

# %%
filtered_data = df[(zscore < 3) & (zscore > -3)]

# %%
filtered_data['SalePrice'].shape
# Out:
# (1438,)

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='SalePrice', data=df)
plt.title('SalePrice Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='SalePrice', data=filtered_data)
plt.tight_layout()
plt.title('SalePrice After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['OverallQual'].quantile(0.25)
q3=df['OverallQual'].quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 2.0

# %%
lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr

# %%
outliers4= df[(df['OverallQual'] > upper_limit) | (df['OverallQual'] < lower_limit)]
outliers4
# Out:
#                           MSSubClass          Zoning Category  LotFrontage  \
# 375             1-STORY 1945 & OLDER  Residential Low Density            0
# 533  1-STORY 1946 & NEWER ALL STYLES  Residential Low Density           50
#
#      LotArea Type of Road   Shape of Property Property Flatness  \
# 375    10020         Pave  Slightly irregular               Low
# 533     5000         Pave             Regular               Low
#
#                     Type of utilities Lot configuration slope of property  \
# 375  All public Utilities (E,G,W,& S)        Inside lot      Severe Slope
# 533  All public Utilities (E,G,W,& S)        Inside lot    Moderate Slope
#
#     Neighborhood Condition1 Condition2 Type of dwelling Style of dwelling  \
# 375      Edwards       Norm       Norm             1Fam            1Story
# 533    Brookside       Norm       Norm             1Fam            1Story
#
#      OverallQual  OverallCond  Year Built  YearRemodAdd Type of roof  \
# ...

# %%
zscore=(df['OverallQual']-df['OverallQual'].mean())/df['OverallQual'].std()
zscore
# Out:
# 0       0.651256
# 1      -0.071812
# 2       0.651256
# 3       0.651256
# 4       1.374324
# 5      -0.794879
# 6       1.374324
# 7       0.651256
# 8       0.651256
# 9      -0.794879
# 10     -0.794879
# 11      2.097391
# 12     -0.794879
# 13      0.651256
# 14     -0.071812
# 15      0.651256
# 16     -0.071812
# 17     -1.517947
# 18     -0.794879
# 19     -0.794879
# 20      1.374324
# 21      0.651256
# 22      1.374324
# 23     -0.794879
# 24     -0.794879
# 25      1.374324
# 26     -0.794879
# 27      1.374324
# 28     -0.794879
# 29     -1.517947
# 30     -1.517947
# 31     -0.794879
# 32      1.374324
# 33     -0.794879
# 34      2.097391
# 35      1.374324
# 36     -0.794879
# 37     -0.794879
# 38     -0.794879
# 39     -1.517947
# 40     -0.071812
# 41     -0.794879
# 42     -0.794879
# 43     -0.794879
# 44     -0.794879
# 45      2.097391
# 46      0.651256
# 47      1.374324
# 48     -1.517947
# 49     -0.794879
# 50     -0.071812
# 51     -0.071812
# ...

# %%
filtered_data1 = df[(zscore < 3) & (zscore > -3)]

# %%
filtered_data1['OverallQual'].shape
# Out:
# (1458,)

# %%
df['OverallQual'].shape
# Out:
# (1460,)

# %%
sns.boxplot(filtered_data1['OverallQual'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='OverallQual', data=df)
plt.title('OverallQual Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='OverallQual', data=filtered_data1)
plt.tight_layout()
plt.title('OverallQual After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['GrLivArea'].quantile(0.25)
q3=df['GrLivArea'].quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 647.25

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_GrLivArea = df['GrLivArea'].mean()
std_GrLivArea = df['GrLivArea'].std()
df['zscore'] = (df['GrLivArea'] - mean_GrLivArea) / std_GrLivArea

# %%
filtered_data3 = df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
sns.boxplot(filtered_data3['GrLivArea'])
# Out:
# <Axes: >

# %%
df['GrLivArea'].shape
# Out:
# (1460,)

# %%
filtered_data3['GrLivArea'].shape
# Out:
# (1444,)

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='GrLivArea', data=df)
plt.title('GrLivArea Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='GrLivArea', data=filtered_data3)
plt.tight_layout()
plt.title('GrLivArea After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['GarageCars'].quantile(0.25)
q3=df['GarageCars'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_GarageCars = df['GarageCars'].mean()
std_GarageCars = df['GarageCars'].std()
df['zscore'] = (df['GarageCars'] - mean_GarageCars) / std_GarageCars

# %%
filtered_data4=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='GarageCars', data=df)
plt.title('GarageCars Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='GarageCars', data=filtered_data4)
plt.tight_layout()
plt.title('GarageCars After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['GarageArea'].quantile(0.25)
q3=df['GarageArea'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_GarageArea = df['GarageArea'].mean()
std_GarageArea = df['GarageArea'].std()
df['zscore'] = (df['GarageArea'] - mean_GarageArea) / std_GarageArea

# %%
filtered_data5=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='GarageArea', data=df)
plt.title('GarageArea Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='GarageArea', data=filtered_data4)
plt.tight_layout()
plt.title('GarageArea After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['TotalBsmtSF'].quantile(0.25)
q3=df['TotalBsmtSF'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_TotalBsmtSF = df['TotalBsmtSF'].mean()
std_TotalBsmtSF = df['TotalBsmtSF'].std()
df['zscore'] = (df['TotalBsmtSF'] - mean_TotalBsmtSF) / std_TotalBsmtSF

# %%
filtered_data6=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='TotalBsmtSF', data=df)
plt.title('TotalBsmtSF Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='TotalBsmtSF', data=filtered_data4)
plt.tight_layout()
plt.title('TotalBsmtSF After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['1stFlrSF'].quantile(0.25)
q3=df['1stFlrSF'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_1stFlrSF = df['1stFlrSF'].mean()
std_1stFlrSF = df['1stFlrSF'].std()
df['zscore'] = (df['1stFlrSF'] - mean_1stFlrSF) / std_1stFlrSF

# %%
filtered_data7=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='1stFlrSF', data=df)
plt.title('1stFlrSF Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='1stFlrSF', data=filtered_data4)
plt.tight_layout()
plt.title('1stFlrSF After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['FullBath'].quantile(0.25)
q3=df['FullBath'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_FullBath= df['FullBath'].mean()
std_FullBath = df['FullBath'].std()
df['zscore'] = (df['FullBath'] - mean_FullBath) / std_FullBath

# %%
filtered_data8=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='FullBath', data=df)
plt.title('FullBath Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='FullBath', data=filtered_data4)
plt.tight_layout()
plt.title('FullBath After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['TotRmsAbvGrd'].quantile(0.25)
q3=df['TotRmsAbvGrd'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_TotRmsAbvGrd = df['TotRmsAbvGrd'].mean()
std_TotRmsAbvGrd = df['TotRmsAbvGrd'].std()
df['zscore'] = (df['TotRmsAbvGrd'] - mean_TotRmsAbvGrd) / std_TotRmsAbvGrd

# %%
filtered_data9=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='TotRmsAbvGrd', data=df)
plt.title('TotRmsAbvGrd Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='TotRmsAbvGrd', data=filtered_data9)
plt.tight_layout()
plt.title('TotRmsAbvGrd After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['Year Built'].quantile(0.25)
q3=df['Year Built'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_YearBuilt = df['Year Built'].mean()
std_YearBuilt = df['Year Built'].std()
df['zscore'] = (df['Year Built'] - mean_YearBuilt) / std_YearBuilt

# %%
filtered_data10=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='Year Built', data=df)
plt.title('Year Built Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='Year Built', data=filtered_data10)
plt.tight_layout()
plt.title('Year Built After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['YearRemodAdd'].quantile(0.25)
q3=df['YearRemodAdd'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_YearRemodAdd = df['YearRemodAdd'].mean()
std_YearRemodAdd = df['YearRemodAdd'].std()
df['zscore'] = (df['YearRemodAdd'] - mean_YearRemodAdd) / std_YearRemodAdd

# %%
filtered_data11=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='YearRemodAdd', data=df)
plt.title('YearRemodAdd Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='YearRemodAdd', data=filtered_data10)
plt.tight_layout()
plt.title('YearRemodAdd After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['Masonry veneer area'].quantile(0.25)
q3=df['Masonry veneer area'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_Masonryveneerarea = df['Masonry veneer area'].mean()
std_Masonryveneerarea = df['Masonry veneer area'].std()
df['zscore'] = (df['Masonry veneer area'] - mean_Masonryveneerarea) / std_Masonryveneerarea

# %%
filtered_data12=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='Masonry veneer area', data=df)
plt.title('Masonry veneer area Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='Masonry veneer area', data=filtered_data12)
plt.tight_layout()
plt.title('Masonryveneerarea After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=df['Fireplaces'].quantile(0.25)
q3=df['Fireplaces'].quantile(0.75)
iqr=q3-q1

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
mean_Fireplaces = df['Fireplaces'].mean()
std_Fireplaces = df['Fireplaces'].std()
df['zscore'] = (df['Fireplaces'] - mean_Fireplaces) / std_Fireplaces

# %%
filtered_data13=df[(df['zscore'] < 3) & (df['zscore'] > -3)]

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y='Fireplaces', data=df)
plt.title('Fireplaces area Before Outlier Removal')

plt.subplot(1, 2, 2)
sns.boxplot(y='Fireplaces', data=filtered_data13)
plt.tight_layout()
plt.title('Fireplaces After Outlier Removal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
